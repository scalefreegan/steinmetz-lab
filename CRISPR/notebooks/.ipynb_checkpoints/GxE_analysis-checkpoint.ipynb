# %% [markdown]
# # Analysis of growth QTLs from GxE paper

# %%
library(ggplot2);
library(plyr);
library(dplyr);
library(reshape2);
library(pheatmap);
library(RColorBrewer);

# %%
gQTL = read.delim("../data/journal.pgen.1003803.s016.TXT",sep="\t", skip=5)
gQTL_rename = gQTL[,4:dim(gQTL)[2]]
rownames(gQTL_rename) = apply(gQTL,1,function(i){paste(i[1:3],collapse="_")})

# %%
head(gQTL)
# Out:
#   chrom   start    stop    SC_BPS        SD    SDMalt    SDRaff       YCB
# 1 chr01  194689  194964 0.9376146 0.9963095 0.9427827 0.9778873 0.9739161
# 2 chr02  164136  164249 0.9376146 0.9963095 0.9385784 0.5595503 0.9999978
# 3 chr02  522911  552978 0.9376146 0.6480658 0.9356478 0.7080419 0.9718821
# 4 chr02  669013  669013 0.9376146 0.7381722 0.9141408 0.2853307 0.8856945
# 5 chr04   17940   22923 0.9483735 0.7414443 0.6387608 0.9777767 0.9718821
# 6 chr04 1416729 1416729 0.9384138 0.9963095 0.8425677 0.9777767 0.9964503
#           YPD   YPD_37C      YPD_BPS YPD_CaCl2  YPD_Fluco YPD_KCl_0.5M
# 1 0.952171413 0.9979204 9.840454e-01 0.8171904 0.89318303   0.99663382
# 2 0.369973535 0.9722205 9.931695e-01 0.7085616 0.91820468   0.66014641
# 3 0.025536909 0.5809135 5.013045e-07 0.7124593 0.01411654   0.02665130
# 4 0.005310404 0.9015955 1.315777e-03 0.6541163 0.89318303   0.42567697
# 5 0.043798801 0.8450279 8.213057e-01 0.7085616 0.96706609   0.03968952
# 6 0.413335701 0.9226594 9.819162e-01 0.9732448 0.89813715   0.34163492
#   YPD_KCl_1M  YPD_NaCl    YPD_Radi  YPD_Rapa YPD_Rapa_10       YPE   YPE_37C
# 1  0.8483619 0.7067893 0.892807439 0.9040796  0.04790628 0.8914208 0.9993564
# 2  0.9786035 0.7411467 0.697337537 0.9330606  0.96955858 0.6098068 0.9993564
# 3  0.2735383 0.6800903 0.001014331 0.2042327  0.01516302 0.3891543 0.9993564
# 4  0.3856046 0.7118343 0.007035857 0.7549886  0.53155710 0.9438680 0.9993564
# 5  0.7256141 0.3809135 0.839153796 0.6060744  0.75260123 0.3891543 0.9993564
# 6  0.8479716 0.6800903 0.875561731 0.9040796  0.90309296 0.6098068 0.9993564
#         YPFruc     YPGly      YPLac      YPMalt YPMalt_37C     YPRaff
# 1 8.152174e-01 0.9476164 0.78363075 0.682615927  0.9858206 0.97987866
# 2 7.796533e-01 0.5116664 0.14649105 0.987574184  0.9858206 0.04380427
# 3 3.077107e-05 0.7584528 0.09727236 0.717345146  0.9858206 0.13202222
# 4 3.077107e-05 0.5802195 0.21667644 0.334898692  0.9858206 0.22124075
# 5 9.002654e-01 0.2109632 0.25797311 0.327485287  0.9858206 0.25577826
# 6 9.981741e-01 0.4095061 0.75749440 0.008313357  0.9858206 0.22124075
#    YPSucrose YP_low_Glu
# 1 0.86481430  0.9600414
# 2 0.72242858  0.6460363
# 3 0.03035355  0.3392328
# 4 0.05647101  0.7767024
# 5 0.16695373  0.3530702
# 6 0.72574733  0.6169512

# %%
pheatmap(t(gQTL_rename), color = brewer.pal(9, "Blues"), breaks=seq(0,1,length.out=10))
# Out:
# plot without title

# %% [markdown]
# ## Correlation between environments

# %%
env_scores = gQTL[,4:dim(gQTL)[2]]
cor_env_scores = cor(env_scores)
toremove1 = apply(cor_env_scores,1,function(i){sum(is.na(i))})>1
toremove2 = apply(cor_env_scores,2,function(i){sum(is.na(i))})>1
cor_env_scores = cor_env_scores[!toremove1,!toremove2]
pheatmap(cor_env_scores,breaks = seq(-1,1,length.out=100))
# Out:
# Warning message:
# In cor(env_scores): the standard deviation is zero
# plot without title

# %% [markdown]
# ## Size of gQTL loci

# %%
gQTL_len = as.data.frame(cbind(gQTL[,1:3],QTL_len=abs(gQTL[,"start"] - gQTL[,"stop"])))
gQTL_len %>% arrange(QTL_len)
# Out:
#    chrom   start    stop QTL_len
# 1  chr02  669013  669013       0
# 2  chr04 1416729 1416729       0
# 3  chr09  271985  271985       0
# 4  chr11  231494  231494       0
# 5  chr11  575206  575206       0
# 6  chr13   26443   26443       0
# 7  chr10  731061  731070       9
# 8  chr12  582969  582978       9
# 9  chr15  487524  487533       9
# 10 chr16  723861  723872      11
# 11 chr16  898658  898678      20
# 12 chr15  798654  798736      82
# 13 chr02  164136  164249     113
# 14 chr11   63715   63901     186
# 15 chr10  529710  529906     196
# 16 chr07  176331  176592     261
# 17 chr01  194689  194964     275
# 18 chr05  191729  192062     333
# 19 chr12  645025  645377     352
# 20 chr10   67942   68549     607
# 21 chr09  420934  423953    3019
# 22 chr05  336234  340922    4688
# 23 chr04   17940   22923    4983
# 24 chr07 1059901 1069033    9132
# 25 chr02  522911  552978   30067
# 26 chr07  809072  839419   30347
# 27 chr14  441876  491226   49350

# %%
hist(abs(gQTL[,"start"] - gQTL[,"stop"]),breaks = 100, main = "gQTL regions, 27 gQTLs", xlab = "Size (bp)")
# Out:
# Plot with title “gQTL regions, 27 gQTLs”
